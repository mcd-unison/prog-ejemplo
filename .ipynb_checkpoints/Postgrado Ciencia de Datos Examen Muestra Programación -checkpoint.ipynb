# %%
import matplotlib.pyplot as plt
import datetime as dt
import pandas as pd

# %%
bikesBD = pd.read_csv('bikes.csv', encoding='utf-8', sep=';')
bikesBD
# Out:
#            Date  Berri 1  Brébeuf (données non disponibles)  \
# 0    01/01/2012       35                                NaN
# 1    02/01/2012       83                                NaN
# 2    03/01/2012      135                                NaN
# 3    04/01/2012      144                                NaN
# 4    05/01/2012      197                                NaN
# ..          ...      ...                                ...
# 305  01/11/2012     2405                                NaN
# 306  02/11/2012     1582                                NaN
# 307  03/11/2012      844                                NaN
# 308  04/11/2012      966                                NaN
# 309  05/11/2012     2247                                NaN
#
#      Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  \
# 0                        0             38             51       26
# 1                        1             68            153       53
# ...

# %%
bikesBD.head(5)  #muestra los primeros 5 renglones
# Out:
#          Date  Berri 1  Brébeuf (données non disponibles)  \
# 0  01/01/2012       35                                NaN
# 1  02/01/2012       83                                NaN
# 2  03/01/2012      135                                NaN
# 3  04/01/2012      144                                NaN
# 4  05/01/2012      197                                NaN
#
#    Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  \
# 0                      0             38             51       26            10
# 1                      1             68            153       53             6
# 2                      2            104            248       89             3
# 3                      1            116            318      111             8
# 4                      2            124            330       97            13
#
#    Rachel1  St-Urbain (données non disponibles)
# 0       16                                  NaN
# 1       43                                  NaN
# ...

# %%
bikesBD.tail(5) #muestra los ultimos 5 renglones
# Out:
#            Date  Berri 1  Brébeuf (données non disponibles)  \
# 305  01/11/2012     2405                                NaN
# 306  02/11/2012     1582                                NaN
# 307  03/11/2012      844                                NaN
# 308  04/11/2012      966                                NaN
# 309  05/11/2012     2247                                NaN
#
#      Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  \
# 305                   1208           1701           3082     2076
# 306                    737           1109           2277     1392
# 307                    380            612           1137      713
# 308                    446            710           1277      692
# 309                   1170           1705           3221     2143
#
#      Pierre-Dupuy  Rachel1  St-Urbain (données non disponibles)
# 305           165     2461                                  NaN
# 306            97     1888                                  NaN
# ...

# %%
bikesBD.dtypes # define rl tipo de datos
# Out:
# Date                                    object
# Berri 1                                  int64
# Brébeuf (données non disponibles)      float64
# Côte-Sainte-Catherine                    int64
# Maisonneuve 1                            int64
# Maisonneuve 2                            int64
# du Parc                                  int64
# Pierre-Dupuy                             int64
# Rachel1                                  int64
# St-Urbain (données non disponibles)    float64
# dtype: object

# %%
bikesBD.shape  # Muestra cantidad de renglones y columnas
# Out:
# (310, 10)

# %%
bikesBD.describe() # muestra datos estadisticos, media, desv. est, valor minimo y maximo etc
# Out:
#            Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  \
# count   310.000000                                0.0             310.000000
# mean   2985.048387                                NaN            1233.351613
# std    2169.271062                                NaN             944.643188
# min      32.000000                                NaN               0.000000
# 25%     596.000000                                NaN             243.250000
# 50%    3128.000000                                NaN            1269.000000
# 75%    4973.250000                                NaN            2003.000000
# max    7077.000000                                NaN            3124.000000
#
#        Maisonneuve 1  Maisonneuve 2      du Parc  Pierre-Dupuy      Rachel1  \
# count     310.000000     310.000000   310.000000    310.000000   310.000000
# mean     1983.325806    3510.261290  1862.983871   1054.306452  2873.483871
# ...

# %%
bikesBD.index # muestra los indices
# Out:
# RangeIndex(start=0, stop=310, step=1)

# %%
bikesBD.loc[1] #muestra los titulos de columnas
# Out:
# Date                                   02/01/2012
# Berri 1                                        83
# Brébeuf (données non disponibles)             NaN
# Côte-Sainte-Catherine                           1
# Maisonneuve 1                                  68
# Maisonneuve 2                                 153
# du Parc                                        53
# Pierre-Dupuy                                    6
# Rachel1                                        43
# St-Urbain (données non disponibles)           NaN
# Name: 1, dtype: object

# %%
bikesBD['Berri 1'] #seleccionamos columna Berri 1
# Out:
# 0        35
# 1        83
# 2       135
# 3       144
# 4       197
#        ...
# 305    2405
# 306    1582
# 307     844
# 308     966
# 309    2247
# Name: Berri 1, Length: 310, dtype: int64

# %%
bikesBD[bikesBD['Berri 1'] > 6500] #ejemplo de filtrado, en este caso valores de columna Berri 1 mayores que 6500
# Out:
#            Date  Berri 1  Brébeuf (données non disponibles)  \
# 165  14/06/2012     6908                                NaN
# 166  15/06/2012     7077                                NaN
# 184  03/07/2012     6712                                NaN
# 186  05/07/2012     6672                                NaN
# 234  22/08/2012     6529                                NaN
# 256  13/09/2012     6520                                NaN
#
#      Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  \
# 165                   2978           4809           7934     4223
# 166                   2469           4999           7663     4053
# 184                   2634           4398           7416     3896
# 186                   2603           4830           7764     3816
# 234                   2671           4513           7065     3774
# 256                   3076           4369           7514     4494
#
#      Pierre-Dupuy  Rachel1  St-Urbain (données non disponibles)
# ...

# %%
bikesBD[(bikesBD['Berri 1'] > 6500) & (bikesBD['Maisonneuve 1'] == 4830)] # filtros con 2 condiciones
# Out:
#            Date  Berri 1  Brébeuf (données non disponibles)  \
# 186  05/07/2012     6672                                NaN
#
#      Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  \
# 186                   2603           4830           7764     3816
#
#      Pierre-Dupuy  Rachel1  St-Urbain (données non disponibles)
# 186          2746     5153                                  NaN

# %%
fecha = '03/07/2012'
bikesBD.query("Date==@fecha") #usando querys con variables
# Out:
#            Date  Berri 1  Brébeuf (données non disponibles)  \
# 184  03/07/2012     6712                                NaN
#
#      Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  \
# 184                   2634           4398           7416     3896
#
#      Pierre-Dupuy  Rachel1  St-Urbain (données non disponibles)
# 184          2606     5462                                  NaN

# %%
bikesBD.sort_values(by="Berri 1", ascending=True) # ordenando por columna de manera ascendente
# Out:
#            Date  Berri 1  Brébeuf (données non disponibles)  \
# 13   14/01/2012       32                                NaN
# 0    01/01/2012       35                                NaN
# 20   21/01/2012       53                                NaN
# 14   15/01/2012       54                                NaN
# 55   25/02/2012       62                                NaN
# ..          ...      ...                                ...
# 234  22/08/2012     6529                                NaN
# 186  05/07/2012     6672                                NaN
# 184  03/07/2012     6712                                NaN
# 165  14/06/2012     6908                                NaN
# 166  15/06/2012     7077                                NaN
#
#      Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  \
# 13                       0             54             56       19
# 0                        0             38             51       26
# ...

# %%
# AGRUPANDO EJEMPLO -> bikesBD.groupby(["Date", "Rachel 1"]).bikesBD['Rachel1'].sum()

# %%
#cambiando formato de fecha 
bikesBD['Date'] = pd.to_datetime(bikesBD['Date'])
bikesBD['Date'] = bikesBD['Date'].dt.strftime('%Y-%m')
bikesBD['month'] = pd.to_datetime(bikesBD['Date']).dt.strftime('%m')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Users\rafas\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1855         try:
# -> 1856             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1857             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-110-cc5f01b0a5e0> in <module>
#       1 #cambiando formato de fecha
# ----> 2 bikesBD['Date'] = pd.to_datetime(bikesBD['Date'])
# ...

# %%
bikesBD
# Out:
#     Date  Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  \
# 0     01       35                                NaN                      0
# 1     02       83                                NaN                      1
# 2     03      135                                NaN                      2
# 3     04      144                                NaN                      1
# 4     05      197                                NaN                      2
# ..   ...      ...                                ...                    ...
# 305   01     2405                                NaN                   1208
# 306   02     1582                                NaN                    737
# 307   03      844                                NaN                    380
# 308   04      966                                NaN                    446
# 309   05     2247                                NaN                   1170
#
# ...

# %%
bikesBD.plot(kind='line', x='Date', y='Berri 1', color='green', figsize=(15,5)) #graficando

# %%
print('La desviacion estándar de la estacion Berri 1 es: ',bikesBD['Berri 1'].std()) #calculando desv stand de estacion Berri 1
# Out:
# La desviacion estándar de la estacion Berri 1 es:  2169.2710617621497

# %%
bikesBD.groupby(bikesBD['Date'].dt.strftime('%m'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-c3750d57bb7f> in <module>
# ----> 1 bikesBD.groupby(bikesBD['Date'].dt.strftime('%m'))
#
# d:\Users\rafas\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# d:\Users\rafas\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
# ...
